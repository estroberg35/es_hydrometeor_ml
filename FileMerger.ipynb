# %%
# Ethan Stroberg
# the goal here is to combine files so that i have a complete HDF5 file with the T and RH data (as well as whatever
# else I might throw in).  
# prerequisites
# plot the frame number vs time and altitude vs time and particle number vs time --> the goal here is to ID when launch happened
# there should be few particles before launch and then a bunch once it launches
# Steps:
# 1. take new file from Sean that has all filenames complete with datetimes and match the datetimes to
#    the image frames in the orignal HDF5
# 2. once matched in time, append the data in the original HDF5 and the data in the CSV to a new HDF5 file
# 3. this new HDF5 file can be read in to the hydrometeor_ML script and run as usual, now including T and RH data
